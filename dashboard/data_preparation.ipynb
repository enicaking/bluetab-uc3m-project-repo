# %%
import os
print(os.getcwd())
# Out:
# c:\Users\bucky\Documents\YEAR 4 - FALL\Data Science Project\blutab-project-repo\bluetab-uc3m-project-repo-1\dashboard

# %%
# Code for generating datasets for the dashboard 

import pandas as pd

# Dataset ---

# %%
# Model metrics ---

# Datasets

df_base = pd.read_csv("../csv_exports/df_base.csv")
df_clean = pd.read_csv("../csv_exports/df_clean.csv")
df_50 = pd.read_csv("../csv_exports/df_exp_50.csv")
df_63 = pd.read_csv("../csv_exports/df_exp_63.csv")
df_random = pd.read_csv("../csv_exports/df_exp_random.csv")
df_same = pd.read_csv("../csv_exports/df_exp_same_prop.csv")

# %%
# Fraud Simulator ---

# %%
df_50
